# %% [markdown]
# **GLOBAL** **SCOPE** **AND** **LOCAL** **SCOPE**

# %%
#A variable is only available from inside the region it is created.This is called Scope

# %%
#Local Scope
#A variable create inside a function belongs to the local scope of that function, and can only be used inside that function.

# %%
def myfunc():
  x = 300
  print(x)
myfunc()
# Out:
# 300

# %%
def myfunc():
  x = 200
  print(x)
myfunc()
print(x)
# Out:
# 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b8a92e96dbf5> in <cell line: 5>()
#       3   print(x)
#       4 myfunc()
# ----> 5 print(x)
#
# NameError: name 'x' is not defined

# %%
#the variable x is not availableoutside the function, but it is available for any function inside the function.

# %% [markdown]
# ## The local variable can be accessed from a function within the function

# %%
def myfunc():
  b = 40
  def myinnerfunc():

    print(b)
  myinnerfunc()

myfunc()
# Out:
# 40

# %%
#Global Scope
#A variable created in the main body of the Python code is a global variable and belongs to the global scope.
#Global variables are available from within any scope, global and local.


#A variable create outside of a function is global and can be used by anyone:

# %%
x = 300
def myfunc():
  print(x)

myfunc()
print(x)
# Out:
# 300
# 300

# %%
#Global Keyword:

#If you want to create a global variable,but are stuck in the local scope, you can use the global keyword.

#the global keyword makes the variable global.

# %%
def myfunc():
  global x
  x = 300

myfunc()
print(x)
# Out:
# 300

# %%
#Also use the global keyword if you want to make a change to a global variables inside a function

# %%
x = 400

def myfunc():
  global x
  x = 60

myfunc()
print(x)
# Out:
# 60
